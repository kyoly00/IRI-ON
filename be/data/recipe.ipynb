# %% [markdown]
# ## 이름 정제

# %%
import pandas as pd
from openai import OpenAI
import time

client = OpenAI(api_key="sktax-XyeKFrq67ZjS4EpsDlrHHXV8it", base_url="https://guest-api.sktax.chat/v1")

# CSV 읽기
recipes = pd.read_csv("recipes_has_url.csv")

def clean_title_with_ai(title: str) -> str:
    prompt = (
        f"다음 요리 제목에서 불필요한 설명, 괄호 속 내용, 수식어를 제거하고 "
        f"순수한 음식 이름만 남겨줘.\n"
        f"입력: {title}\n"
        f"출력:"
    )

    completion = client.chat.completions.create(
        model="ax4",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    return completion.choices[0].message.content.strip()

# 한 행씩 처리
cleaned_titles = []
for idx, row in recipes[:30].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 1/251 처리 완료: 소고기 고추장
# 2/251 처리 완료: 비름나물
# 3/251 처리 완료: 스팸감자조림
# 4/251 처리 완료: 어느덧 여름 성수기가 다가오면 아삭아삭 오이고추를 이용한 만능 된장소스가 생각나기 마련이죠. 이 콘텐츠의 제목은 "여름반찬 아삭오이고추 만능된장무침 레시피"였습니다.
#
# 마치 깨끗한 화이트보드를 고른 것처럼, 불필요한 성분들을 빼보면, 아래와 같은 맛있는 이름이 남네요.
#
# **오이고추된장무침**
#
# May your taste buds explore these simple yet delectable bursts of summer! (여러분은 여름의 상쾌한 맛을 간단한 이 음식으로부터 찾게 될 거예요!)
# 5/251 처리 완료: 참치쌈장
# 6/251 처리 완료: 베이컨덮밥
# 7/251 처리 완료: 양배추만두
# 8/251 처리 완료: 햄 감자채볶음
# 9/251 처리 완료: 토마토간장샐러드
# 10/251 처리 완료: 취나물무침
# 11/251 처리 완료: 감자꽈리고추조림
# 12/251 처리 완료: 크래미깻잎전
# 13/251 처리 완료: 팽이버섯 덮밥
# 14/251 처리 완료: 달걀조림
# 15/251 처리 완료: 두부피자
# 16/251 처리 완료: 마늘종볶음
# 17/251 처리 완료: 대파소시지달걀볶음밥
# 18/251 처리 완료: 팽이버섯
# 19/251 처리 완료: 마늘쫑 소시지 볶음
# 20/251 처리 완료: 비엔나 강정
# 21/251 처리 완료: 고구마떡
# 22/251 처리 완료: 알배추무침
# 23/251 처리 완료: 돼지고기감자조림
# 24/251 처리 완료: 두부볶음
# 25/251 처리 완료: 오징어채
# 26/251 처리 완료: 우동
# 27/251 처리 완료: 새우콘치즈
# 28/251 처리 완료: 우유달걀카레
# 29/251 처리 완료: 애호박전
# 30/251 처리 완료: 양파속 닭가슴살

# %%
for idx, row in recipes[30:60].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 31/251 처리 완료: 얼갈이드레싱무침
# 32/251 처리 완료: 메추리알 곤약 볶음 (*졸인 메추리알 곤약 볶음으로 변형해 보았습니다. 상황에 맞게 수정하세요.)
# 33/251 처리 완료: 소시지양배추덮밥
# 34/251 처리 완료: 소고기유부초밥
# 35/251 처리 완료: 새우 부추전
# 36/251 처리 완료: 달걀찜
# 37/251 처리 완료: 새송이버섯 간장버터구이
# 38/251 처리 완료: 순살간장치킨
# 39/251 처리 완료: 메추리알조림
# 40/251 처리 완료: 닭가슴살 양배추말이
# 41/251 처리 완료: 오징어 간장조림
# 42/251 처리 완료: 치킨 스테이크
# 43/251 처리 완료: - 크림소스 치킨스테이크
# 44/251 처리 완료: 달걀버거
# 45/251 처리 완료: 돌나물사과무침
# 46/251 처리 완료: 양배추 참치덮밥
# 47/251 처리 완료: 참치 스테이크
# 48/251 처리 완료: 돼지볶음
# 49/251 처리 완료: 순두부 요리
# 50/251 처리 완료: 새우어묵
# 51/251 처리 완료: 콘치즈 토스트
# 52/251 처리 완료: 맛탕
# 53/251 처리 완료: 팽이버섯조림
# 54/251 처리 완료: 삼겹깐풍덮밥
# 55/251 처리 완료: 부추비빔밥
# 56/251 처리 완료: 콘치즈파이
# 57/251 처리 완료: 배추나물 무침
# 58/251 처리 완료: 냉파스타
# 59/251 처리 완료: 카레닭봉구이
# 60/251 처리 완료: 새우숙주볶음

# %%
for idx, row in recipes[60:90].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 61/251 처리 완료: 참치 양파볶음
# 62/251 처리 완료: 묵은지간장국수
# 63/251 처리 완료: 새우밥버거
# 64/251 처리 완료: - 식빵팝콘
# - 별미
# 65/251 처리 완료: 애호박 간장국수
# 66/251 처리 완료: 컵브라우니
# 67/251 처리 완료: 닭꼬치
# 68/251 처리 완료: 두부탕수
# 69/251 처리 완료: 베이컨말이
# 70/251 처리 완료: 차돌배기떡볶음
# 71/251 처리 완료: 파스타
# 72/251 처리 완료: 밥피자
# 73/251 처리 완료: 냉동미니돈까스, 난자완스
# 74/251 처리 완료: 어묵
# 75/251 처리 완료: 표고버섯꽈리고추볶음
# 76/251 처리 완료: 버섯채소구이
# 77/251 처리 완료: 순두부조림
# 78/251 처리 완료: 상추겉절이
# 79/251 처리 완료: KFC 비스켓
# 80/251 처리 완료: * 볶음밥, 버터만두볶음밥
# 81/251 처리 완료: 밥말이
# 82/251 처리 완료: 감자 크래커
# 83/251 처리 완료: 양배추참치덮밥
# 84/251 처리 완료: 컵피자
# 85/251 처리 완료: 차돌박이부추무침
# 86/251 처리 완료: 수란마요밥
# 87/251 처리 완료: 새송이버섯소고기볶음
# 88/251 처리 완료: 팽이버섯 조림
# 89/251 처리 완료: 치즈 불닭
# 90/251 처리 완료: 깐풍만두

# %%
for idx, row in recipes[90:120].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 91/251 처리 완료: 옥수수치즈빵
# 92/251 처리 완료: 훈제오리 부추무침
# 93/251 처리 완료: 소고기표고버섯덮밥
# 94/251 처리 완료: 에너지바
# 95/251 처리 완료: 목살 양념구이
# 96/251 처리 완료: 새송이간장버터구이
# 97/251 처리 완료: 깻잎말이
# 98/251 처리 완료: 비빔만두
# 99/251 처리 완료: 소고기숙주볶음
# 100/251 처리 완료: 베떡베떡
# 101/251 처리 완료: 베이비 슈
# 102/251 처리 완료: 표고버섯볶음
# 103/251 처리 완료: 참치 마요볼
# 104/251 처리 완료: 감자스팸간장조림
# 105/251 처리 완료: 두부강정
# 106/251 처리 완료: 삼겹살 차슈덮밥
# 107/251 처리 완료: 닭고기 스테이크
# 108/251 처리 완료: 목살 스테이크
# 109/251 처리 완료: 모닝빵
# 110/251 처리 완료: 칠리새우
# 111/251 처리 완료: 버터 스팸동
# 112/251 처리 완료: 꽈리고추삼겹살볶음
# 113/251 처리 완료: 콘꼬노미야끼
# 114/251 처리 완료: 양배추쌈
# 115/251 처리 완료: 고르곤졸라 토스트
# 116/251 처리 완료: 김 장아찌
# 117/251 처리 완료: 돼지고기마늘조림
# 118/251 처리 완료: 베이컨덮밥
# 119/251 처리 완료: 두부쉐이크
# 120/251 처리 완료: 오이치킨보트

# %%
for idx, row in recipes[120:150].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 121/251 처리 완료: 비빔만두
# 122/251 처리 완료: 부타동
# 123/251 처리 완료: 오레오 치즈케이크
# 124/251 처리 완료: 스팸 맛탕
# 125/251 처리 완료: 카레주먹밥
# 126/251 처리 완료: 부타동
# 127/251 처리 완료: 토마토부르스케타
# 128/251 처리 완료: 장떡만둣국
# 129/251 처리 완료: 식빵팝콘
# 130/251 처리 완료: 통마늘표고버섯볶음
# 131/251 처리 완료: 두부 파프리카전, 두부, 달걀
# 132/251 처리 완료: 고구마에그슬럿
# 133/251 처리 완료: 빨간 오뎅 / Spicy fish cakes
# 134/251 처리 완료: 고구마채전
# 135/251 처리 완료: 바치 디 다마
# 136/251 처리 완료: 파프리카 피자
# 137/251 처리 완료: 허니윙
# 138/251 처리 완료: 감자전
# 139/251 처리 완료: 토스트
# 140/251 처리 완료: 야채샐러드빵
# 141/251 처리 완료: 무침만두
# 142/251 처리 완료: 떡볶음
# 143/251 처리 완료: 버섯볶음두부면
# 144/251 처리 완료: 카페모카쿠키슈
# 145/251 처리 완료: 양파덮밥
# 146/251 처리 완료: 컵케이크
# 147/251 처리 완료: 오이들깨무침
# 148/251 처리 완료: 물비빔국수
# 149/251 처리 완료: 불참치장
# 150/251 처리 완료: 치즈 공구마

# %%
for idx, row in recipes[150:180].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 151/251 처리 완료: 모카 케이크
# 152/251 처리 완료: 숙주볶음
# 153/251 처리 완료: 치즈 쿠키
# 154/251 처리 완료: 초코 비스코티
# 155/251 처리 완료: 고추장황태채볶음
# 156/251 처리 완료: 된장삼겹살덮밥
# 157/251 처리 완료: 오징어말이
# 158/251 처리 완료: 애호박 새우마요 볶음
# 159/251 처리 완료: 돼지갈비
# 160/251 처리 완료: 두부스테이크
# 161/251 처리 완료: 두부 마요네즈
# 162/251 처리 완료: 크림 새송이
# 163/251 처리 완료: 오이롤초밥
# 164/251 처리 완료: 콘치즈 고로케
# 165/251 처리 완료: 표고버섯 덮밥
# 166/251 처리 완료: 가지탕수
# 167/251 처리 완료: 그라탱
# 168/251 처리 완료: 우유달걀카레
# 169/251 처리 완료: 오일파스타
# 170/251 처리 완료: 황태채 버터구이
# 171/251 처리 완료: 대패대파구이
# 172/251 처리 완료: 베이컨치즈밥말이
# 173/251 처리 완료: 양파튀김
# 174/251 처리 완료: 사과 케이크
# 175/251 처리 완료: 새송이
# 176/251 처리 완료: 훈제오리볶음
# 오리훈제볶음
# 양배추볶음
# 177/251 처리 완료: 파프리카된장무침
# 178/251 처리 완료: 닭마볶음밥
# 179/251 처리 완료: 우삼겹 덮밥 규동
# 180/251 처리 완료: 가지 라자냐

# %%
cleaned_titles = cleaned_titles[:-30]
cleaned_titles
# Out:
# ['소고기 고추장',
#  '비름나물',
#  '스팸감자조림',
#  '어느덧 여름 성수기가 다가오면 아삭아삭 오이고추를 이용한 만능 된장소스가 생각나기 마련이죠. 이 콘텐츠의 제목은 "여름반찬 아삭오이고추 만능된장무침 레시피"였습니다.\n\n마치 깨끗한 화이트보드를 고른 것처럼, 불필요한 성분들을 빼보면, 아래와 같은 맛있는 이름이 남네요.\n\n**오이고추된장무침**\n\nMay your taste buds explore these simple yet delectable bursts of summer! (여러분은 여름의 상쾌한 맛을 간단한 이 음식으로부터 찾게 될 거예요!)',
#  '참치쌈장',
#  '베이컨덮밥',
#  '양배추만두',
#  '햄 감자채볶음',
#  '토마토간장샐러드',
#  '취나물무침',
#  '감자꽈리고추조림',
#  '크래미깻잎전',
#  '팽이버섯 덮밥',
#  '달걀조림',
#  '두부피자',
#  '마늘종볶음',
#  '대파소시지달걀볶음밥',
#  '팽이버섯',
#  '마늘쫑 소시지 볶음',
#  '비엔나 강정',
#  '고구마떡',
#  '알배추무침',
#  '돼지고기감자조림',
#  '두부볶음',
#  '오징어채',
#  '우동',
#  '새우콘치즈',
#  '우유달걀카레',
#  '애호박전',
#  '양파속 닭가슴살',
#  '얼갈이드레싱무침',
#  '메추리알 곤약 볶음 (*졸인 메추리알 곤약 볶음으로 변형해 보았습니다. 상황에 맞게 수정하세요.)',
#  '소시지양배추덮밥',
#  '소고기유부초밥',
#  '새우 부추전',
#  '달걀찜',
#  '새송이버섯 간장버터구이',
#  '순살간장치킨',
#  '메추리알조림',
#  '닭가슴살 양배추말이',
#  '오징어 간장조림',
#  '치킨 스테이크',
#  '- 크림소스 치킨스테이크',
#  '달걀버거',
#  '돌나물사과무침',
#  '양배추 참치덮밥',
#  '참치 스테이크',
#  '돼지볶음',
#  '순두부 요리',
#  '새우어묵',
#  '콘치즈 토스트',
#  '맛탕',
#  '팽이버섯조림',
#  '삼겹깐풍덮밥',
#  '부추비빔밥',
#  '콘치즈파이',
#  '배추나물 무침',
#  '냉파스타',
#  '카레닭봉구이',
#  '새우숙주볶음',
#  '참치 양파볶음',
#  '묵은지간장국수',
#  '새우밥버거',
#  '- 식빵팝콘\n- 별미',
#  '애호박 간장국수',
#  '컵브라우니',
#  '닭꼬치',
#  '두부탕수',
#  '베이컨말이',
#  '차돌배기떡볶음',
#  '파스타',
#  '밥피자',
#  '냉동미니돈까스, 난자완스',
#  '어묵',
#  '표고버섯꽈리고추볶음',
#  '버섯채소구이',
#  '순두부조림',
#  '상추겉절이',
#  'KFC 비스켓',
#  '* 볶음밥, 버터만두볶음밥',
#  '밥말이',
#  '감자 크래커',
#  '양배추참치덮밥',
#  '컵피자',
#  '차돌박이부추무침',
#  '수란마요밥',
#  '새송이버섯소고기볶음',
#  '팽이버섯 조림',
#  '치즈 불닭',
#  '깐풍만두',
#  '옥수수치즈빵',
#  '훈제오리 부추무침',
#  '소고기표고버섯덮밥',
#  '에너지바',
#  '목살 양념구이',
#  '새송이간장버터구이',
#  '깻잎말이',
#  '비빔만두',
#  '소고기숙주볶음',
#  '베떡베떡',
#  '베이비 슈',
#  '표고버섯볶음',
#  '참치 마요볼',
#  '감자스팸간장조림',
#  '두부강정',
#  '삼겹살 차슈덮밥',
#  '닭고기 스테이크',
#  '목살 스테이크',
#  '모닝빵',
#  '칠리새우',
#  '버터 스팸동',
#  '꽈리고추삼겹살볶음',
#  '콘꼬노미야끼',
#  '양배추쌈',
#  '고르곤졸라 토스트',
#  '김 장아찌',
#  '돼지고기마늘조림',
#  '베이컨덮밥',
#  '두부쉐이크',
#  '오이치킨보트',
#  '비빔만두',
#  '부타동',
#  '오레오 치즈케이크',
#  '스팸 맛탕',
#  '카레주먹밥',
#  '부타동',
#  '토마토부르스케타',
#  '장떡만둣국',
#  '식빵팝콘',
#  '통마늘표고버섯볶음',
#  '두부 파프리카전, 두부, 달걀',
#  '고구마에그슬럿',
#  '빨간 오뎅 / Spicy fish cakes',
#  '고구마채전',
#  '바치 디 다마',
#  '파프리카 피자',
#  '허니윙',
#  '감자전',
#  '토스트',
#  '야채샐러드빵',
#  '무침만두',
#  '떡볶음',
#  '버섯볶음두부면',
#  '카페모카쿠키슈',
#  '양파덮밥',
#  '컵케이크',
#  '오이들깨무침',
#  '물비빔국수',
#  '불참치장',
#  '치즈 공구마',
#  '모카 케이크',
#  '숙주볶음',
#  '치즈 쿠키',
#  '초코 비스코티',
#  '고추장황태채볶음',
#  '된장삼겹살덮밥',
#  '오징어말이',
#  '애호박 새우마요 볶음',
#  '돼지갈비',
#  '두부스테이크',
#  '두부 마요네즈',
#  '크림 새송이',
#  '오이롤초밥',
#  '콘치즈 고로케',
#  '표고버섯 덮밥',
#  '가지탕수',
#  '그라탱',
#  '우유달걀카레',
#  '오일파스타',
#  '황태채 버터구이',
#  '대패대파구이',
#  '베이컨치즈밥말이',
#  '양파튀김',
#  '사과 케이크',
#  '새송이',
#  '훈제오리볶음\n오리훈제볶음\n양배추볶음',
#  '파프리카된장무침',
#  '닭마볶음밥',
#  '우삼겹 덮밥 규동',
#  '가지 라자냐']

# %%
for idx, row in recipes[180:210].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 181/251 처리 완료: 닭죽
# 182/251 처리 완료: 참치 파스타, 두부면 파스타
# 183/251 처리 완료: 떡감자
# 184/251 처리 완료: 느타리두루치기
# 185/251 처리 완료: 오이무침
# 186/251 처리 완료: 콩나물무침
# 187/251 처리 완료: 간장두부장
# 188/251 처리 완료: 돈까스 김치나베
# 189/251 처리 완료: 얼큰만둣국
# 190/251 처리 완료: 시금치 플랫브레드 피자
# 191/251 처리 완료: 마늘빵
# 마늘빵
# 마늘빵
# 식빵
# 192/251 처리 완료: 돼지불백
# 193/251 처리 완료: 녹차머핀
# 194/251 처리 완료: 참치맛나니
# 195/251 처리 완료: 프리타타
# 196/251 처리 완료: 아망디오 쇼콜라
# 197/251 처리 완료: 할로윈 브라우니 쿠키
# 198/251 처리 완료: 연어 파피요트
# 199/251 처리 완료: 새송이버섯 고추장구이
# 200/251 처리 완료: 뢰스티
# 201/251 처리 완료: 츄러스
# 202/251 처리 완료: 어묵비빔국수
# 203/251 처리 완료: 김치마요우동
# 204/251 처리 완료: 하트파이 팔미에
# 205/251 처리 완료: 달걀떡볶이
# 206/251 처리 완료: 소고기볶음
# 207/251 처리 완료: 양파햄치즈빵
# 208/251 처리 완료: 게살버거
# 209/251 처리 완료: 크랜베리 화이트 초코 쿠키
# 210/251 처리 완료: 모카 컵케이크

# %%
for idx, row in recipes[210:240].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 211/251 처리 완료: 어향치킨
# 212/251 처리 완료: 체리클라푸티
# 213/251 처리 완료: 순두부 계란
# 214/251 처리 완료: 투움바파스타
# 215/251 처리 완료: 오레오 크림치즈 머핀
# 216/251 처리 완료: 버터구이 진미채
# 217/251 처리 완료: 함양파 링전
# 218/251 처리 완료: 스팸아보카도덮밥
# 219/251 처리 완료: 고추참치비빔우동
# 220/251 처리 완료: 면두부 크림파스타
# 221/251 처리 완료: 스팸마요 덮밥
# 222/251 처리 완료: 사과 크렘블 파이
# 223/251 처리 완료: 스카레
# 224/251 처리 완료: 어묵노미야끼
# 225/251 처리 완료: 콘치즈
# 226/251 처리 완료: 식빵 러스크 (에어프라이어)
# 227/251 처리 완료: 소고기쪽파말이
# 228/251 처리 완료: 딸기잼 쿠키
# 과일잼 쿠키
# 229/251 처리 완료: 계란탕
# 230/251 처리 완료: 오징어볶음
# 231/251 처리 완료: 시나몬 롤 쿠키
# 232/251 처리 완료: 가지덮밥
# 233/251 처리 완료: 시래기지짐
# 234/251 처리 완료: 파마산 치즈 쿠키
# 235/251 처리 완료: 소시지강정
# 236/251 처리 완료: 식빵팝콘
# 237/251 처리 완료: 베이컨말이
# 238/251 처리 완료: 퍼지 브라우니
# 239/251 처리 완료: 대파토스트
# 240/251 처리 완료: 소시지콩나물찜

# %%
for idx, row in recipes[240:251].iterrows():
    cleaned = clean_title_with_ai(row["title"])
    cleaned_titles.append(cleaned)
    
    print(f"{idx+1}/{len(recipes)} 처리 완료: {cleaned}")
# Out:
# 241/251 처리 완료: 아보카도 베이컨구이
# 242/251 처리 완료: 고구마조림
# 243/251 처리 완료: 주먹밥
# 244/251 처리 완료: 양배추어묵볶음
# 245/251 처리 완료: 구운 참치 주먹밥
# 246/251 처리 완료: 퐁크러쉬 쉐이크
# 247/251 처리 완료: 소시지 배추 롤
# 248/251 처리 완료: 돼지불백
# 249/251 처리 완료: 등갈비
# 250/251 처리 완료: 초코칩쿠키
# 251/251 처리 완료: 커피콩 쿠키

# %%
recipes["title"] = cleaned_titles
recipes
# Out:
#      Unnamed: 0                                         url  \
# 0             0  https://www.10000recipe.com/recipe/7056958
# 1             1  https://www.10000recipe.com/recipe/7056078
# 2             2  https://www.10000recipe.com/recipe/6984517
# 3             3  https://www.10000recipe.com/recipe/7029097
# 4             4  https://www.10000recipe.com/recipe/7004229
# ..          ...                                         ...
# 246         246  https://www.10000recipe.com/recipe/6873183
# 247         247  https://www.10000recipe.com/recipe/6944180
# 248         248  https://www.10000recipe.com/recipe/6876326
# 249         249  https://www.10000recipe.com/recipe/6925791
# 250         250  https://www.10000recipe.com/recipe/6892104
#
#                                             main_image     author  \
# 0    https://recipe1.ezmember.co.kr/cache/recipe/20...       반이짝이
# 1    https://recipe1.ezmember.co.kr/cache/recipe/20...       블루픽콕
# 2    https://recipe1.ezmember.co.kr/cache/recipe/20...     냠냠간단요리
# 3    https://recipe1.ezmember.co.kr/cache/recipe/20...     햇살머금은집
# 4    https://recipe1.ezmember.co.kr/cache/recipe/20...      유튜버아뜨
# ..                                                 ...        ...
# 246  https://recipe1.ezmember.co.kr/cache/recipe/20...  C Channel
# 247  https://recipe1.ezmember.co.kr/cache/recipe/20...      두율이아빠
# 248  https://recipe1.ezmember.co.kr/cache/recipe/20...     만개의레시피
# 249  https://recipe1.ezmember.co.kr/cache/recipe/20...     안젤라베이킹
# 250  https://recipe1.ezmember.co.kr/cache/recipe/20...         효썸
#
#                                                  title  \
# 0                                              소고기 고추장
# 1                                                 비름나물
# 2                                               스팸감자조림
# 3    어느덧 여름 성수기가 다가오면 아삭아삭 오이고추를 이용한 만능 된장소스가 생각나기 ...
# 4                                                 참치쌈장
# ..                                                 ...
# 246                                           소시지 배추 롤
# 247                                               돼지불백
# 248                                                등갈비
# 249                                              초코칩쿠키
# 250                                             커피콩 쿠키
#
#                                            description servings     time  \
# 0    더운 여름에 입맛 없을 때 열무김치나 생야채 넣고 비빔밥 만들어먹거나 달걀프라이만 ...      2인분   20분 이내
# 1    여름에 먹으면 맛있는 나물인 비름나물을 무쳐보았어요. 고추장 양념으로 무치면 된장찌...      4인분   30분 이내
# 2                                          단짠단짠 맛있어요^^      2인분   10분 이내
# 3                   그냥 먹어도 맛있는 아삭오이고추 된장으로 맛있게 무쳐 볼게요.      2인분    5분 이내
# 4    다른 반찬 필요없이 이거 하나면 밥 한공기 뚝딱 갓한 따끈한 밥에 쌈장올려 쌈싸먹으...      3인분   15분 이내
# ..                                                 ...      ...      ...
# 246                                      넘나 맛있는 소시지 반찬      2인분   30분 이내
# 247                               이 양념 하나면 우리집이 기사식당!!      3인분   30분 이내
# 248  된장 앤 간장! 된앤간의 신레시피!\n양념 등갈비 찜 납시오♥\n내가 오늘 누울 자...      2인분   60분 이내
# 249  예전에 호텔에서 근무했을 때 배웠던 쿠키 레시피입니다.\n버터가 적게 들어가서 가볍...   6인분 이상   2시간 이상
# 250  커피를 좋아하시는 분들께 추천합니다!! 적당히 달면서 약간 쌉싸름한 맛이 있기 때문...   6인분 이상  120분 이내
#
#     difficulty                                          materials  \
# 0           초급  다진소고기 200g, 양파 1/4개, 대파 1/4대, 다진마늘 1큰술, 진간장 1/...
# 1          아무나  비름나물1봉 400g, 소금 1/2Ts, 고추장 2Ts, 다진 마늘 1Ts, 설탕 ...
# 2           초급  감자 2개, 스팸 200g, 진간장 4스푼, 설탕 4스푼, 후추 조금, 올리고당 1...
# 3          아무나  오이고추 3개, 된장 1t, 고춧가루 1/2t, 통깨 약간, 올리고당 1t, 참기름 1t
# 4           초급  참치 1캔, 양파 1개, 청양고추 3개, 기름 1T, 물 1/2컵, 된장 3T, 고...
# ..         ...                                                ...
# 246        아무나                    배추 1/4개, 소시지 10개, 후추 , 케첩 , 겨자
# 247        아무나  돼지앞다리살 600g, 다진양파 1/4개, 다진대파 1/2대, 다진마늘 1큰술, 진...
# 248        아무나  등갈비 1kg, 물 적당히, 된장 1T, 파채 1줌, 통마늘 5개, 간장 8T, 설...
# 249        아무나  버터 190g, 설탕 283g, 계란 180g, 박력분 350g, 코코아 파우더 1...
# 250        아무나  무염버터 60g, 설탕 40g, 인스턴트커피 3g, 우유 15g, 노른자 1개, 박...
#
#                                              tools  \
# 0    키친타올, 믹싱볼, 도마, 조리용나이프, 계량스푼, 프라이팬, 요리스푼, 완성그릇
# 1            볼, 냄비, 계량스푼, 조리주걱, 채반, 도마, 조리용나이프, 접시
# 2                                              NaN
# 3                            도마, 조리용나이프, 볼, 스푼, 접시
# 4                            인덱스도마, 믹싱볼, 요리스푼, 볶음팬
# ..                                             ...
# 246                                            NaN
# 247                                            NaN
# 248                                            NaN
# 249                                            NaN
# 250                                            NaN
#
#                                              video_url  \
# 0    https://tv.naver.com/embed/21142287?autoPlay=true
# 1            https://www.youtube.com/embed/hcgBbhPK_4c
# 2            https://www.youtube.com/embed/fHbpTTzEe_E
# 3    https://tv.naver.com/embed/52277225?autoPlay=true
# 4            https://www.youtube.com/embed/_pF_uCKx9XU
# ..                                                 ...
# 246  http://tv.kakao.com/embed/player/cliplink/3729...
# 247          https://www.youtube.com/embed/uT6TygtX1qA
# 248          https://www.youtube.com/embed/ypySHKxED0Q
# 249          https://www.youtube.com/embed/oBNb6APmJBw
# 250          https://www.youtube.com/embed/198PQt8kWBM
#
#                                                  steps  \
# 0    [{'text': '다짐육 200g 정도를 준비한 다음 먼저 키친타월로 핏물을 제거...
# 1    [{'text': '비름나물 한 봉지의 무게를 달아보았더니 대략 400g이 나왔어요...
# 2    [{'text': '감자는 깍뚝 썰어 2분 데쳐주세요\n강불', 'images': ...
# 3    [{'text': '아삭하고 구수한 오이고추 된장무침 만들기 해 볼께요.', 'im...
# 4    [{'text': '양파,고추 잘게썰기', 'images': ['https://re...
# ..                                                 ...
# 246  [{'text': '배추를 1장씩 부드러워질 때까지 데친다.', 'images': ...
# 247  [{'text': '계량스푼은 집에서 사용하는 8cc 정도의 밥숟가락입니다.\n양파...
# 248  [{'text': '등갈비는 찬물에 1시간 정도 담가 핏물을 뺀다.\n등갈비 1kg...
# 249  [{'text': '박력분, 코코아파우더, 베이킹파우더는 3번 체 쳐서 준비한다.'...
# 250  [{'text': '인스턴트커피는 미리 뜨겁게 데운 우유를 넣고 녹여주세요.', '...
#
#                                           final_images  \
# 0    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 1    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 2                                                   []
# 3                                                   []
# 4    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# ..                                                 ...
# 246  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 247  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 248  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 249                                                 []
# 250  ['https://recipe1.ezmember.co.kr/cache/recipe/...
#
#                                                   tips
# 0    나물 반찬 만들어둔게 있어서 비빔밥 만들어먹을 때 약고추장 넣고 슥슥 비벼서 먹었더...
# 1    비름나물은 데치기전 굵고 억센 줄기는 골라내고 데쳐야 부드러운 나물을 먹을 수 있어...
# 2                                                  NaN
# 3                                                  NaN
# 4    취향에 맞게 고추는 더 넣어도 좋아요 싱겁게 드신다면 두부, 감자 ,애호박, 버섯 ...
# ..                                                 ...
# 246                                                NaN
# 247  1. 매운맛을 올리시려면 땡초 1~2개를 썰어서 양념에 넣으세요.\n2. 고추가루는...
# 248                                                NaN
# 249  [만들기 전에]\n-버터는 미리 실온에 꺼내두어 완전히 말랑한 상태로 준비한다.\n...
# 250                                                NaN
#
# [251 rows x 15 columns]

# %%
recipes.to_csv("recipes_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 recipes.to_csv("recipes_cleaned.csv")
#
# NameError: name 'recipes' is not defined

# %%
# title 길이가 15 이하인 행만 남기기
recipes = recipes[recipes['title'].str.len() <= 15]

# 결과 저장
recipes.to_csv("recipes_cleaned.csv", index=False)

# %% [markdown]
# ## 카테고리 추가

# %%
import pandas as pd
from openai import OpenAI
import time

client = OpenAI(api_key="sktax-XyeKFrq67ZjS4EpsDlrHHXV8it", base_url="https://guest-api.sktax.chat/v1")

# %%
# AI에게 카테고리 분류 요청
def categorize_with_ai(title):
    """
    title을 입력하면 AI가 한식, 중식, 양식, 디저트, 음료 등으로 분류
    """
    prompt = f"다음 음식 제목을 보고 [한식, 중식, 양식, 일식, 간식, 기타] 중 가장 적절한 카테고리 하나만 선택하세요.\n선택한 카테고리의 단어만 출력하고, 다른 말은 절대 하지 마세요.\n\n음식 제목: {title}"
    completion = client.chat.completions.create(
        model="ax4",
        messages=[{"role": "user", "content": prompt}]
    )
    # AI 응답에서 텍스트 추출
    category = completion.choices[0].message.content.strip()
    return category

# %%
# CSV 불러오기
recipes = pd.read_csv("recipes_cleaned.csv")

# category 컬럼 초기화
categories = []

# %%
for idx, row in recipes[:30].iterrows():
    cat = categorize_with_ai(row["title"])
    categories.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")
# Out:
# 1/246 처리 완료: 소고기 고추장 -> 한식
# 2/246 처리 완료: 비름나물 -> 한식
# 3/246 처리 완료: 스팸감자조림 -> 한식
# 4/246 처리 완료: 참치쌈장 -> 한식
# 5/246 처리 완료: 베이컨덮밥 -> 양식
# 6/246 처리 완료: 양배추만두 -> 중식
# 7/246 처리 완료: 햄 감자채볶음 -> 한식
# 8/246 처리 완료: 토마토간장샐러드 -> 양식
# 9/246 처리 완료: 취나물무침 -> 한식
# 10/246 처리 완료: 감자꽈리고추조림 -> 한식
# 11/246 처리 완료: 크래미깻잎전 -> 한식
# 12/246 처리 완료: 팽이버섯 덮밥 -> 일식
# 13/246 처리 완료: 달걀조림 -> 한식
# 14/246 처리 완료: 두부피자 -> 양식
# 15/246 처리 완료: 마늘종볶음 -> 한식
# 16/246 처리 완료: 대파소시지달걀볶음밥 -> 중식
# 17/246 처리 완료: 팽이버섯 -> 간식
# 18/246 처리 완료: 마늘쫑 소시지 볶음 -> 양식
# 19/246 처리 완료: 비엔나 강정 -> 양식
# 20/246 처리 완료: 고구마떡 -> 간식
# 21/246 처리 완료: 알배추무침 -> 한식
# 22/246 처리 완료: 돼지고기감자조림 -> 한식
# 23/246 처리 완료: 두부볶음 -> 한식
# 24/246 처리 완료: 오징어채 -> 간식
# 25/246 처리 완료: 우동 -> 일식
# 26/246 처리 완료: 새우콘치즈 -> 간식
# 27/246 처리 완료: 우유달걀카레 -> 중식
# 28/246 처리 완료: 애호박전 -> 한식
# 29/246 처리 완료: 양파속 닭가슴살 -> 간식
# 30/246 처리 완료: 얼갈이드레싱무침 -> 한식

# %%
for idx, row in recipes[30:60].iterrows():
    cat = categorize_with_ai(row["title"])
    categories.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")
# Out:
# 31/246 처리 완료: 소시지양배추덮밥 -> 양식
# 32/246 처리 완료: 소고기유부초밥 -> 일식
# 33/246 처리 완료: 새우 부추전 -> 한식
# 34/246 처리 완료: 달걀찜 -> 한식
# 35/246 처리 완료: 새송이버섯 간장버터구이 -> 양식
# 36/246 처리 완료: 순살간장치킨 -> 한식
# 37/246 처리 완료: 메추리알조림 -> 한식
# 38/246 처리 완료: 닭가슴살 양배추말이 -> 한식
# 39/246 처리 완료: 오징어 간장조림 -> 한식
# 40/246 처리 완료: 치킨 스테이크 -> 양식
# 41/246 처리 완료: - 크림소스 치킨스테이크 -> 양식
# 42/246 처리 완료: 달걀버거 -> 양식
# 43/246 처리 완료: 돌나물사과무침 -> 한식
# 44/246 처리 완료: 양배추 참치덮밥 -> 일식
# 45/246 처리 완료: 참치 스테이크 -> 양식
# 46/246 처리 완료: 돼지볶음 -> 한식
# 47/246 처리 완료: 순두부 요리 -> 한식
# 48/246 처리 완료: 새우어묵 -> 간식
# 49/246 처리 완료: 콘치즈 토스트 -> 간식
# 50/246 처리 완료: 맛탕 -> 간식
# 51/246 처리 완료: 팽이버섯조림 -> 한식
# 52/246 처리 완료: 삼겹깐풍덮밥 -> 중식
# 53/246 처리 완료: 부추비빔밥 -> 한식
# 54/246 처리 완료: 콘치즈파이 -> 간식
# 55/246 처리 완료: 배추나물 무침 -> 한식
# 56/246 처리 완료: 냉파스타 -> 양식
# 57/246 처리 완료: 카레닭봉구이 -> 일식
# 58/246 처리 완료: 새우숙주볶음 -> 중식
# 59/246 처리 완료: 참치 양파볶음 -> 중식
# 60/246 처리 완료: 묵은지간장국수 -> 한식

# %%
print(len(categories))
# Out:
# 60

# %%
c = []
for idx, row in recipes[60:90].iterrows():
    cat = categorize_with_ai(row["title"])
    c.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")

categories += c
len(categories)
# Out:
# 61/246 처리 완료: 새우밥버거 -> 간식
# 62/246 처리 완료: - 식빵팝콘
# - 별미 -> 간식
# 63/246 처리 완료: 애호박 간장국수 -> 일식
# 64/246 처리 완료: 컵브라우니 -> 간식
# 65/246 처리 완료: 닭꼬치 -> 간식
# 66/246 처리 완료: 두부탕수 -> 중식
# 67/246 처리 완료: 베이컨말이 -> 양식
# 68/246 처리 완료: 차돌배기떡볶음 -> 한식
# 69/246 처리 완료: 파스타 -> 양식
# 70/246 처리 완료: 밥피자 -> 간식
# 71/246 처리 완료: 냉동미니돈까스, 난자완스 -> 양식
# 72/246 처리 완료: 어묵 -> 간식
# 73/246 처리 완료: 표고버섯꽈리고추볶음 -> 한식
# 74/246 처리 완료: 버섯채소구이 -> 한식
# 75/246 처리 완료: 순두부조림 -> 한식
# 76/246 처리 완료: 상추겉절이 -> 한식
# 77/246 처리 완료: KFC 비스켓 -> 간식
# 78/246 처리 완료: * 볶음밥, 버터만두볶음밥 -> 중식
# 79/246 처리 완료: 밥말이 -> 한식
# 80/246 처리 완료: 감자 크래커 -> 간식
# 81/246 처리 완료: 양배추참치덮밥 -> 한식
# 82/246 처리 완료: 컵피자 -> 간식
# 83/246 처리 완료: 차돌박이부추무침 -> 한식
# 84/246 처리 완료: 수란마요밥 -> 한식
# 85/246 처리 완료: 새송이버섯소고기볶음 -> 중식
# 86/246 처리 완료: 팽이버섯 조림 -> 한식
# 87/246 처리 완료: 치즈 불닭 -> 간식
# 88/246 처리 완료: 깐풍만두 -> 중식
# 89/246 처리 완료: 옥수수치즈빵 -> 간식
# 90/246 처리 완료: 훈제오리 부추무침 -> 한식
# 120

# %%
c = []
for idx, row in recipes[90:120].iterrows():
    cat = categorize_with_ai(row["title"])
    c.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")

categories += c
len(categories)
# Out:
# 91/246 처리 완료: 소고기표고버섯덮밥 -> 일식
# 92/246 처리 완료: 에너지바 -> 간식
# 93/246 처리 완료: 목살 양념구이 -> 한식
# 94/246 처리 완료: 새송이간장버터구이 -> 양식
# 95/246 처리 완료: 깻잎말이 -> 한식
# 96/246 처리 완료: 비빔만두 -> 한식
# 97/246 처리 완료: 소고기숙주볶음 -> 한식
# 98/246 처리 완료: 베떡베떡 -> 간식
# 99/246 처리 완료: 베이비 슈 -> 간식
# 100/246 처리 완료: 표고버섯볶음 -> 한식
# 101/246 처리 완료: 참치 마요볼 -> 일식
# 102/246 처리 완료: 감자스팸간장조림 -> 한식
# 103/246 처리 완료: 두부강정 -> 한식
# 104/246 처리 완료: 삼겹살 차슈덮밥 -> 일식
# 105/246 처리 완료: 닭고기 스테이크 -> 양식
# 106/246 처리 완료: 목살 스테이크 -> 양식
# 107/246 처리 완료: 모닝빵 -> 간식
# 108/246 처리 완료: 칠리새우 -> 중식
# 109/246 처리 완료: 버터 스팸동 -> 양식
# 110/246 처리 완료: 꽈리고추삼겹살볶음 -> 한식
# 111/246 처리 완료: 콘꼬노미야끼 -> 일식
# 112/246 처리 완료: 양배추쌈 -> 한식
# 113/246 처리 완료: 고르곤졸라 토스트 -> 양식
# 114/246 처리 완료: 김 장아찌 -> 한식
# 115/246 처리 완료: 돼지고기마늘조림 -> 한식
# 116/246 처리 완료: 베이컨덮밥 -> 양식
# 117/246 처리 완료: 두부쉐이크 -> 간식
# 118/246 처리 완료: 오이치킨보트 -> 한식
# 119/246 처리 완료: 비빔만두 -> 한식
# 120/246 처리 완료: 부타동 -> 일식
# 120

# %%
c = []
for idx, row in recipes[120:150].iterrows():
    cat = categorize_with_ai(row["title"])
    c.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")

categories += c
len(categories)
# Out:
# 121/246 처리 완료: 오레오 치즈케이크 -> 간식
# 122/246 처리 완료: 스팸 맛탕 -> 간식
# 123/246 처리 완료: 카레주먹밥 -> 간식
# 124/246 처리 완료: 부타동 -> 일식
# 125/246 처리 완료: 토마토부르스케타 -> 양식
# 126/246 처리 완료: 장떡만둣국 -> 한식
# 127/246 처리 완료: 식빵팝콘 -> 간식
# 128/246 처리 완료: 통마늘표고버섯볶음 -> 한식
# 129/246 처리 완료: 고구마에그슬럿 -> 간식
# 130/246 처리 완료: 고구마채전 -> 간식
# 131/246 처리 완료: 바치 디 다마 -> 중식
# 132/246 처리 완료: 파프리카 피자 -> 양식
# 133/246 처리 완료: 허니윙 -> 간식
# 134/246 처리 완료: 감자전 -> 한식
# 135/246 처리 완료: 토스트 -> 간식
# 136/246 처리 완료: 야채샐러드빵 -> 간식
# 137/246 처리 완료: 무침만두 -> 한식
# 138/246 처리 완료: 떡볶음 -> 한식
# 139/246 처리 완료: 버섯볶음두부면 -> 한식
# 140/246 처리 완료: 카페모카쿠키슈 -> 간식
# 141/246 처리 완료: 양파덮밥 -> 일식
# 142/246 처리 완료: 컵케이크 -> 간식
# 143/246 처리 완료: 오이들깨무침 -> 한식
# 144/246 처리 완료: 물비빔국수 -> 한식
# 145/246 처리 완료: 불참치장 -> 일식
# 146/246 처리 완료: 치즈 공구마 -> 간식
# 147/246 처리 완료: 모카 케이크 -> 간식
# 148/246 처리 완료: 숙주볶음 -> 중식
# 149/246 처리 완료: 치즈 쿠키 -> 간식
# 150/246 처리 완료: 초코 비스코티 -> 간식
# 150

# %%
c = []
for idx, row in recipes[150:180].iterrows():
    cat = categorize_with_ai(row["title"])
    c.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")

categories += c
len(categories)
# Out:
# 151/246 처리 완료: 고추장황태채볶음 -> 한식
# 152/246 처리 완료: 된장삼겹살덮밥 -> 한식
# 153/246 처리 완료: 오징어말이 -> 일식
# 154/246 처리 완료: 애호박 새우마요 볶음 -> 한식
# 155/246 처리 완료: 돼지갈비 -> 한식
# 156/246 처리 완료: 두부스테이크 -> 양식
# 157/246 처리 완료: 두부 마요네즈 -> 한식
# 158/246 처리 완료: 크림 새송이 -> 양식
# 159/246 처리 완료: 오이롤초밥 -> 일식
# 160/246 처리 완료: 콘치즈 고로케 -> 간식
# 161/246 처리 완료: 표고버섯 덮밥 -> 일식
# 162/246 처리 완료: 가지탕수 -> 중식
# 163/246 처리 완료: 그라탱 -> 양식
# 164/246 처리 완료: 우유달걀카레 -> 간식
# 165/246 처리 완료: 오일파스타 -> 양식
# 166/246 처리 완료: 황태채 버터구이 -> 한식
# 167/246 처리 완료: 대패대파구이 -> 한식
# 168/246 처리 완료: 베이컨치즈밥말이 -> 양식
# 169/246 처리 완료: 양파튀김 -> 간식
# 170/246 처리 완료: 사과 케이크 -> 간식
# 171/246 처리 완료: 새송이 -> 한식
# 172/246 처리 완료: 파프리카된장무침 -> 한식
# 173/246 처리 완료: 닭마볶음밥 -> 중식
# 174/246 처리 완료: 우삼겹 덮밥 규동 -> 일식
# 175/246 처리 완료: 가지 라자냐 -> 양식
# 176/246 처리 완료: 닭죽 -> 한식
# 177/246 처리 완료: 참치 파스타, 두부면 파스타 -> 양식
# 178/246 처리 완료: 떡감자 -> 간식
# 179/246 처리 완료: 느타리두루치기 -> 한식
# 180/246 처리 완료: 오이무침 -> 한식
# 180

# %%
c = []
for idx, row in recipes[180:210].iterrows():
    cat = categorize_with_ai(row["title"])
    c.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")

categories += c
len(categories)
# Out:
# 181/246 처리 완료: 콩나물무침 -> 한식
# 182/246 처리 완료: 간장두부장 -> 중식
# 183/246 처리 완료: 돈까스 김치나베 -> 일식
# 184/246 처리 완료: 얼큰만둣국 -> 한식
# 185/246 처리 완료: 시금치 플랫브레드 피자 -> 양식
# 186/246 처리 완료: 마늘빵
# 마늘빵
# 마늘빵
# 식빵 -> 양식
# 187/246 처리 완료: 돼지불백 -> 한식
# 188/246 처리 완료: 녹차머핀 -> 간식
# 189/246 처리 완료: 참치맛나니 -> 일식
# 190/246 처리 완료: 프리타타 -> 양식
# 191/246 처리 완료: 아망디오 쇼콜라 -> 간식
# 192/246 처리 완료: 할로윈 브라우니 쿠키 -> 간식
# 193/246 처리 완료: 연어 파피요트 -> 양식
# 194/246 처리 완료: 새송이버섯 고추장구이 -> 한식
# 195/246 처리 완료: 뢰스티 -> 간식
# 196/246 처리 완료: 츄러스 -> 간식
# 197/246 처리 완료: 어묵비빔국수 -> 간식
# 198/246 처리 완료: 김치마요우동 -> 일식
# 199/246 처리 완료: 하트파이 팔미에 -> 간식
# 200/246 처리 완료: 달걀떡볶이 -> 한식
# 201/246 처리 완료: 소고기볶음 -> 한식
# 202/246 처리 완료: 양파햄치즈빵 -> 간식
# 203/246 처리 완료: 게살버거 -> 양식
# 204/246 처리 완료: 크랜베리 화이트 초코 쿠키 -> 간식
# 205/246 처리 완료: 모카 컵케이크 -> 간식
# 206/246 처리 완료: 어향치킨 -> 중식
# 207/246 처리 완료: 체리클라푸티 -> 간식
# 208/246 처리 완료: 순두부 계란 -> 한식
# 209/246 처리 완료: 투움바파스타 -> 양식
# 210/246 처리 완료: 오레오 크림치즈 머핀 -> 간식
# 210

# %%
c = []
for idx, row in recipes[210:246].iterrows():
    cat = categorize_with_ai(row["title"])
    c.append(cat)
    print(f"{idx+1}/{len(recipes)} 처리 완료: {row['title']} -> {cat}")

categories += c
len(categories)
# Out:
# 211/246 처리 완료: 버터구이 진미채 -> 간식
# 212/246 처리 완료: 함양파 링전 -> 한식
# 213/246 처리 완료: 스팸아보카도덮밥 -> 일식
# 214/246 처리 완료: 고추참치비빔우동 -> 일식
# 215/246 처리 완료: 면두부 크림파스타 -> 양식
# 216/246 처리 완료: 스팸마요 덮밥 -> 일식
# 217/246 처리 완료: 사과 크렘블 파이 -> 간식
# 218/246 처리 완료: 스카레 -> 아라비아
# 219/246 처리 완료: 어묵노미야끼 -> 기타
# 220/246 처리 완료: 콘치즈 -> 간식
# 221/246 처리 완료: 식빵 러스크 (에어프라이어) -> 간식
# 222/246 처리 완료: 소고기쪽파말이 -> 한식
# 223/246 처리 완료: 딸기잼 쿠키
# 과일잼 쿠키 -> 간식
# 224/246 처리 완료: 계란탕 -> 한식
# 225/246 처리 완료: 오징어볶음 -> 한식
# 226/246 처리 완료: 시나몬 롤 쿠키 -> 간식
# 227/246 처리 완료: 가지덮밥 -> 일식
# 228/246 처리 완료: 시래기지짐 -> 한식
# 229/246 처리 완료: 파마산 치즈 쿠키 -> 간식
# 230/246 처리 완료: 소시지강정 -> 간식
# 231/246 처리 완료: 식빵팝콘 -> 간식
# 232/246 처리 완료: 베이컨말이 -> 간식
# 233/246 처리 완료: 퍼지 브라우니 -> 간식
# 234/246 처리 완료: 대파토스트 -> 간식
# 235/246 처리 완료: 소시지콩나물찜 -> 한식
# 236/246 처리 완료: 아보카도 베이컨구이 -> 양식
# 237/246 처리 완료: 고구마조림 -> 간식
# 238/246 처리 완료: 주먹밥 -> 한식
# 239/246 처리 완료: 양배추어묵볶음 -> 한식
# 240/246 처리 완료: 구운 참치 주먹밥 -> 일식
# 241/246 처리 완료: 퐁크러쉬 쉐이크 -> 간식
# 242/246 처리 완료: 소시지 배추 롤 -> 간식
# 243/246 처리 완료: 돼지불백 -> 한식
# 244/246 처리 완료: 등갈비 -> 한식
# 245/246 처리 완료: 초코칩쿠키 -> 간식
# 246/246 처리 완료: 커피콩 쿠키 -> 간식
# 246

# %%
len(categories)
# Out:
# 210

# %%
recipes1 = recipes
recipes1.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
recipes1.head(1)
# Out:
#                                           url  \
# 0  https://www.10000recipe.com/recipe/7056958
#
#                                           main_image author    title  \
# 0  https://recipe1.ezmember.co.kr/cache/recipe/20...   반이짝이  소고기 고추장
#
#                                          description servings    time  \
# 0  더운 여름에 입맛 없을 때 열무김치나 생야채 넣고 비빔밥 만들어먹거나 달걀프라이만 ...      2인분  20분 이내
#
#   difficulty                                          materials  \
# 0         초급  다진소고기 200g, 양파 1/4개, 대파 1/4대, 다진마늘 1큰술, 진간장 1/...
#
#                                            tools  \
# 0  키친타올, 믹싱볼, 도마, 조리용나이프, 계량스푼, 프라이팬, 요리스푼, 완성그릇
#
#                                            video_url  \
# 0  https://tv.naver.com/embed/21142287?autoPlay=true
#
#                                                steps  \
# 0  [{'text': '다짐육 200g 정도를 준비한 다음 먼저 키친타월로 핏물을 제거...
#
#                                         final_images  \
# 0  ['https://recipe1.ezmember.co.kr/cache/recipe/...
#
#                                                 tips
# 0  나물 반찬 만들어둔게 있어서 비빔밥 만들어먹을 때 약고추장 넣고 슥슥 비벼서 먹었더...

# %%
recipes.shape
# Out:
# (246, 14)

# %%
recipes["category"] = categories
recipes.head(1)
# Out:
#                                           url  \
# 0  https://www.10000recipe.com/recipe/7056958
#
#                                           main_image author    title  \
# 0  https://recipe1.ezmember.co.kr/cache/recipe/20...   반이짝이  소고기 고추장
#
#                                          description servings    time  \
# 0  더운 여름에 입맛 없을 때 열무김치나 생야채 넣고 비빔밥 만들어먹거나 달걀프라이만 ...      2인분  20분 이내
#
#   difficulty                                          materials  \
# 0         초급  다진소고기 200g, 양파 1/4개, 대파 1/4대, 다진마늘 1큰술, 진간장 1/...
#
#                                            tools  \
# 0  키친타올, 믹싱볼, 도마, 조리용나이프, 계량스푼, 프라이팬, 요리스푼, 완성그릇
#
#                                            video_url  \
# 0  https://tv.naver.com/embed/21142287?autoPlay=true
#
#                                                steps  \
# 0  [{'text': '다짐육 200g 정도를 준비한 다음 먼저 키친타월로 핏물을 제거...
#
#                                         final_images  \
# 0  ['https://recipe1.ezmember.co.kr/cache/recipe/...
#
#                                                 tips category
# 0  나물 반찬 만들어둔게 있어서 비빔밥 만들어먹을 때 약고추장 넣고 슥슥 비벼서 먹었더...       한식

# %%
recipes.to_csv("recipes_with_categories.csv", index=False)

# %% [markdown]
# ## 시간, 인분 int화

# %%
import pandas as pd

# %%
recipes = pd.read_csv('recipes_with_categories.csv')

# %%
# 허용 값 리스트
allowed_values = ['초급', '아무나', '중급', '고급']
# 조건 필터
recipes = recipes[recipes['difficulty'].isin(allowed_values)]


# '인분'으로 끝나는 행만 유지
recipes = recipes[recipes['servings'].str.endswith('인분', na=False)]
# '인분' 글자 제거
recipes['servings'] = recipes['servings'].str.replace('인분', '', regex=False)


# '분 이내'으로 끝나는 행만 유지
recipes = recipes[recipes['time'].str.endswith('분 이내', na=False)]
# '분 이내' 글자 제거
recipes['time'] = recipes['time'].str.replace('분 이내', '', regex=False)

recipes.head(3)
# Out:
#                                           url  \
# 0  https://www.10000recipe.com/recipe/7056958
# 1  https://www.10000recipe.com/recipe/7056078
# 2  https://www.10000recipe.com/recipe/6984517
#
#                                           main_image  author    title  \
# 0  https://recipe1.ezmember.co.kr/cache/recipe/20...    반이짝이  소고기 고추장
# 1  https://recipe1.ezmember.co.kr/cache/recipe/20...    블루픽콕     비름나물
# 2  https://recipe1.ezmember.co.kr/cache/recipe/20...  냠냠간단요리   스팸감자조림
#
#                                          description servings time difficulty  \
# 0  더운 여름에 입맛 없을 때 열무김치나 생야채 넣고 비빔밥 만들어먹거나 달걀프라이만 ...        2   20         초급
# 1  여름에 먹으면 맛있는 나물인 비름나물을 무쳐보았어요. 고추장 양념으로 무치면 된장찌...        4   30        아무나
# 2                                        단짠단짠 맛있어요^^        2   10         초급
#
#                                            materials  \
# 0  다진소고기 200g, 양파 1/4개, 대파 1/4대, 다진마늘 1큰술, 진간장 1/...
# 1  비름나물1봉 400g, 소금 1/2Ts, 고추장 2Ts, 다진 마늘 1Ts, 설탕 ...
# 2  감자 2개, 스팸 200g, 진간장 4스푼, 설탕 4스푼, 후추 조금, 올리고당 1...
#
#                                            tools  \
# 0  키친타올, 믹싱볼, 도마, 조리용나이프, 계량스푼, 프라이팬, 요리스푼, 완성그릇
# 1          볼, 냄비, 계량스푼, 조리주걱, 채반, 도마, 조리용나이프, 접시
# 2                                            NaN
#
#                                            video_url  \
# 0  https://tv.naver.com/embed/21142287?autoPlay=true
# 1          https://www.youtube.com/embed/hcgBbhPK_4c
# 2          https://www.youtube.com/embed/fHbpTTzEe_E
#
#                                                steps  \
# 0  [{'text': '다짐육 200g 정도를 준비한 다음 먼저 키친타월로 핏물을 제거...
# 1  [{'text': '비름나물 한 봉지의 무게를 달아보았더니 대략 400g이 나왔어요...
# 2  [{'text': '감자는 깍뚝 썰어 2분 데쳐주세요\n강불', 'images': ...
#
#                                         final_images  \
# 0  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 1  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 2                                                 []
#
#                                                 tips category
# 0  나물 반찬 만들어둔게 있어서 비빔밥 만들어먹을 때 약고추장 넣고 슥슥 비벼서 먹었더...       한식
# 1  비름나물은 데치기전 굵고 억센 줄기는 골라내고 데쳐야 부드러운 나물을 먹을 수 있어...       한식
# 2                                                NaN       한식

# %%
recipes.to_csv("recipes.csv", index=False)

# %% [markdown]
# ## 도구 있는 레시피만 필터링

# %%
import pandas as pd

# %%
recipes = pd.read_csv('recipes.csv')
recipes = recipes.dropna(subset=['title', 'tools', 'materials'])
recipes
# Out:
#                                             url  \
# 0    https://www.10000recipe.com/recipe/7056958
# 1    https://www.10000recipe.com/recipe/7056078
# 3    https://www.10000recipe.com/recipe/7004229
# 5    https://www.10000recipe.com/recipe/7045377
# 6    https://www.10000recipe.com/recipe/7033948
# 7    https://www.10000recipe.com/recipe/7052761
# 8    https://www.10000recipe.com/recipe/7023640
# 9    https://www.10000recipe.com/recipe/7032079
# 10   https://www.10000recipe.com/recipe/7018922
# 13   https://www.10000recipe.com/recipe/7004960
# 20   https://www.10000recipe.com/recipe/7006926
# 21   https://www.10000recipe.com/recipe/7002427
# 24   https://www.10000recipe.com/recipe/7002301
# 27   https://www.10000recipe.com/recipe/7042593
# 29   https://www.10000recipe.com/recipe/7037873
# 31   https://www.10000recipe.com/recipe/7053709
# 34   https://www.10000recipe.com/recipe/6894323
# 52   https://www.10000recipe.com/recipe/7027008
# 58   https://www.10000recipe.com/recipe/7044761
# 62   https://www.10000recipe.com/recipe/7056654
# 67   https://www.10000recipe.com/recipe/7039774
# 72   https://www.10000recipe.com/recipe/7020548
# 82   https://www.10000recipe.com/recipe/7004654
# 84   https://www.10000recipe.com/recipe/7010976
# 91   https://www.10000recipe.com/recipe/6925795
# 101  https://www.10000recipe.com/recipe/7002443
# 108  https://www.10000recipe.com/recipe/7000243
# 110  https://www.10000recipe.com/recipe/7020842
# 112  https://www.10000recipe.com/recipe/7054093
# 121  https://www.10000recipe.com/recipe/7027181
# 127  https://www.10000recipe.com/recipe/7022304
# 135  https://www.10000recipe.com/recipe/7031537
# 145  https://www.10000recipe.com/recipe/7035279
# 155  https://www.10000recipe.com/recipe/7028555
# 166  https://www.10000recipe.com/recipe/7039931
# 185  https://www.10000recipe.com/recipe/6998851
# 188  https://www.10000recipe.com/recipe/7045801
# 209  https://www.10000recipe.com/recipe/7044002
# 211  https://www.10000recipe.com/recipe/7004106
# 221  https://www.10000recipe.com/recipe/6899335
#
#                                             main_image        author  \
# 0    https://recipe1.ezmember.co.kr/cache/recipe/20...          반이짝이
# 1    https://recipe1.ezmember.co.kr/cache/recipe/20...          블루픽콕
# 3    https://recipe1.ezmember.co.kr/cache/recipe/20...         유튜버아뜨
# 5    https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 6    https://recipe1.ezmember.co.kr/cache/recipe/20...          반이짝이
# 7    https://recipe1.ezmember.co.kr/cache/recipe/20...         아임레시피
# 8    https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 9    https://recipe1.ezmember.co.kr/cache/recipe/20...         아임레시피
# 10   https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 13   https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 20   https://recipe1.ezmember.co.kr/cache/recipe/20...        즐거운날랄라
# 21   https://recipe1.ezmember.co.kr/cache/recipe/20...        즐거운날랄라
# 24   https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 27   https://recipe1.ezmember.co.kr/cache/recipe/20...         음식중개사
# 29   https://recipe1.ezmember.co.kr/cache/recipe/20...      김진옥요리가좋다
# 31   https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 34   https://recipe1.ezmember.co.kr/cache/recipe/20...          뽀유TV
# 52   https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 58   https://recipe1.ezmember.co.kr/cache/recipe/20...        햇살머금은집
# 62   https://recipe1.ezmember.co.kr/cache/recipe/20...  smallhealing
# 67   https://recipe1.ezmember.co.kr/cache/recipe/20...      푸드디렉터요알남
# 72   https://recipe1.ezmember.co.kr/cache/recipe/20...         아임레시피
# 82   https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 84   https://recipe1.ezmember.co.kr/cache/recipe/20...        즐거운날랄라
# 91   https://recipe1.ezmember.co.kr/cache/recipe/20...         두율이아빠
# 101  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 108  https://recipe1.ezmember.co.kr/cache/recipe/20...        즐거운날랄라
# 110  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 112  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 121  https://recipe1.ezmember.co.kr/cache/recipe/20...          동주키친
# 127  https://recipe1.ezmember.co.kr/cache/recipe/20...           콩설기
# 135  https://recipe1.ezmember.co.kr/cache/recipe/20...        냠냠간단요리
# 145  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 155  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 166  https://recipe1.ezmember.co.kr/cache/recipe/20...     lemontree
# 185  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 188  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 209  https://recipe1.ezmember.co.kr/cache/recipe/20...        만개의레시피
# 211  https://recipe1.ezmember.co.kr/cache/recipe/20...        즐거운날랄라
# 221  https://recipe1.ezmember.co.kr/cache/recipe/20...         집밥이박사
#
#                title                                        description  \
# 0            소고기 고추장  더운 여름에 입맛 없을 때 열무김치나 생야채 넣고 비빔밥 만들어먹거나 달걀프라이만 ...
# 1               비름나물  여름에 먹으면 맛있는 나물인 비름나물을 무쳐보았어요. 고추장 양념으로 무치면 된장찌...
# 3               참치쌈장  다른 반찬 필요없이 이거 하나면 밥 한공기 뚝딱 갓한 따끈한 밥에 쌈장올려 쌈싸먹으...
# 5              양배추만두  만두는 먹고 싶은데 피까지 만들긴 귀찮고..그럴 땐 라이스페이퍼를 활용해 보세요!\...
# 6            햄 감자채볶음  아이들반찬으로 간단하게 만들기 좋은 감자채볶음을 스팸을 넣고 고소하고 짭조름하게 볶았어요
# 7           토마토간장샐러드  일본식 토마토샐러드는 간장소스에 먹는다고 해요~ 토마토와 간장이 조합이라.. 이거 ...
# 8              취나물무침  취나물을 쌈장으로 조물조물 무쳐보세요. 향긋한 취나물을 간단하고 맛있게! 순식간에 ...
# 9           감자꽈리고추조림  감자가 맛난 계절 꽈리고추 넣어 맛있게 졸여보세요~ 이건 정말 말이 필요 없어지는 ...
# 10            크래미깻잎전  크래미와 깻잎으로 만드는 맛있는 반찬 향긋한 매력이 있는 크래미깻잎전 크래미를 깻잎...
# 13              두부피자  다이어트 중 피자가 먹고 싶을 때 빵 대신 두부를 이용해 피자를 만들어 보세요. 담...
# 20             알배추무침                         불쓰기 힘든 요즘 불없이 간단하게 만들어 보세요
# 21          돼지고기감자조림  자박자박 매~콤~한 국물에 푹 익힌 감자와 야들야들 부드러운 돼지고기..... 밥 ...
# 24                우동  국물 없이 간단하게 비벼먹는 우동 명란, 버터, 김가루, 쪽파 등을 올리고 쯔유를 ...
# 27              애호박전  오늘은 흔한 애호박전에 고명 하나를 더해 꽃보다 예쁜 '애호박전' 레시피를 소개할게...
# 29          얼갈이드레싱무침  안녕하세요 김진옥입니다. 제가 금요일마다 어르신들 섬기는 봉사를 가는데요.. 지난 ...
# 31           소고기유부초밥  요즘 날씨가 정말 좋아서 나들이 많이 가시죠? 나들이에는 역시 뭐니뭐니해도 도시락!...
# 34      새송이버섯 간장버터구이  마땅한 반찬 없을때 새송이버섯 간장버터구이 한번 만들어 보세요!단짠단짠 양념에 고기...
# 52             부추비빔밥  된장소스로 고소하고 감칠맛 있는 비빔밥 참치, 부추, 계란에 특제 된장소스를 넣고 ...
# 58           참치 양파볶음                       그냥 먹어도 맛있는 참치양파볶음 만들기 해 볼께요.
# 62          애호박 간장국수  언니네 산지직송 방송에서 영화배우 박정민이 쉬지 않고 먹으며 감탄한 반할 수밖에 없...
# 67           차돌배기떡볶음  달콤하고 짭조름한 맛이 일품인 차돌박이 떡볶음입니다. 매운 거 못 드시는 분들은 한...
# 72        표고버섯꽈리고추볶음  쫄깃쫄깃한 표고버섯에 꽈리고추를 볶아 밑반찬을 만들어보세요 이거 정말 너무너무 맛있...
# 82          차돌박이부추무침  날씨가 더워지면 입맛이 떨어지곤 하는데요. 이럴때 새콤한 음식을 먹으면 침샘이 자극...
# 84        새송이버섯소고기볶음                    새송이버섯과 소고기를 볶아보세요~! 정말 맛있습니다 ^^
# 91           목살 양념구이  즉석양념장으로 간장베이스 소스를 만들어 돼지목살을 졸여 봤어요~ 양념장에 숙성시킨 ...
# 101         닭고기 스테이크  닭다리살을 활용한 닭고기스테이크 큼직한 닭다리살과 가니쉬를 노릇하게 굽고 간장과 케...
# 108             양배추쌈  양배추와 두부 건강에도 좋고 다이어트에도 좋은 식재료이죠~ 양배추 두부 이렇게 먹으...
# 110         돼지고기마늘조림  구운마늘 듬뿍 넣어 만드는 돼지고기조림\r\n쫄깃한 목살로 맛있게 만드는 밥반찬\r...
# 112            두부쉐이크  아침을 챙겨 먹는 건 정말 힘든 일이에요! 바쁜 아침에 간단하게 뭘 먹을 수 있을까...
# 121        통마늘표고버섯볶음  나이가 들면 피로가 쌓이면, 면역력이 저하되면 각종 질병에 노출이 되기 때문에 고생...
# 127              감자전  평소에도 감자전을 참 좋아해요. 원조 감자전인 갈아서 만드는 게 제일 맛있지만 조금...
# 135            물비빔국수                       새콤달콤 무더운 여름에 입맛 당기는 레시피 입니다!
# 145      애호박 새우마요 볶음  탱글탱글한 새우와 부드러운 애호박의 환상 조화! 새우와 애호박을 마요네즈로 부드럽게...
# 155            오일파스타  제오리를 볶아 나온 기름에 달달 볶은 시금치가 감칠맛을 더한 간단한 파스타에요. 훈...
# 166  참치 파스타, 두부면 파스타  살 찔 걱정 없이 스트레스를 날려줄 매콤한 토마토 참치 파스타 소개해요:) 매콤한 ...
# 185           어묵비빔국수  간단하고 맛있는 비빔국수 만드는 법! 양념장, 어묵, 소면으로 순식간에 한끼 완성 ...
# 188            소고기볶음  장조림인 것 같지만 조금 다른 꽈리고추 소고기볶음 레시피에요. 간장, 굴소스로 간을...
# 209              계란탕  다시 기온이 훅 떨어지고나니 따뜻한 국물이 당기는 건..역시나..\r\n몽글몽글 계...
# 211             가지덮밥  가지의 폴리페놀 성분이 혈당 수치 조절하는데 도움이 되고 섬유질 함량이 높아 포만감...
# 221          양배추어묵볶음                     어묵볶음의 부족한 아삭함을 양배추가 확실히 잡아주네요.
#
#      servings  time difficulty  \
# 0           2    20         초급
# 1           4    30        아무나
# 3           3    15         초급
# 5           2    20        아무나
# 6           2    20         초급
# 7           2    10        아무나
# 8           2    15        아무나
# 9           2    15        아무나
# 10          2    15        아무나
# 13          3    30        아무나
# 20          2    10        아무나
# 21          3    20        아무나
# 24          1    10        아무나
# 27          4    20        아무나
# 29          4    10        아무나
# 31          2    20        아무나
# 34          2    10        아무나
# 52          1    15        아무나
# 58          4     5        아무나
# 62          2    30         초급
# 67          2    20        아무나
# 72          2    15        아무나
# 82          3    15        아무나
# 84          3    15        아무나
# 91          2    20         초급
# 101         2    30        아무나
# 108         3    20        아무나
# 110         2    30        아무나
# 112         2    15        아무나
# 121         4    30        아무나
# 127         3    30        아무나
# 135         1    10         초급
# 145         1    20        아무나
# 155         1    30        아무나
# 166         2    20         초급
# 185         1    15        아무나
# 188         2    30        아무나
# 209         4    30        아무나
# 211         1    10        아무나
# 221         2    10        아무나
#
#                                              materials  \
# 0    다진소고기 200g, 양파 1/4개, 대파 1/4대, 다진마늘 1큰술, 진간장 1/...
# 1    비름나물1봉 400g, 소금 1/2Ts, 고추장 2Ts, 다진 마늘 1Ts, 설탕 ...
# 3    참치 1캔, 양파 1개, 청양고추 3개, 기름 1T, 물 1/2컵, 된장 3T, 고...
# 5    양배추 1/4개, 참치 1캔, 달걀 2개, 라이스페이퍼 10장, 굴소스 1T, 후추...
# 6    감자큰것 2개, 스팸 80g, 양파 1/4개, 당근 30g, 마늘 1작은술, 소금 ...
# 7    토마토 2개, 상추 1/2장, 소금 2꼬집, 진간장 1/2큰술, 매실액 1/2큰술,...
# 8    취나물 150g, 통깨 1숟가락, 소금 1/2숟가락, 대파 1/3대, 쌈장 2숟가락...
# 9    감자 3~4개, 꽈리고추작은거 20개, 다진마늘 1큰술, 고추장 1큰술, 된장 1작...
# 10      크래미 1팩, 깻잎 6장, 달걀 2개, 부침가루 3숟가락, 소금 약간, 식용유 약간
# 13   두부 1모, 토마토소스 6숟가락, 양파 1/4개, 방울토마토 3개, 닭가슴살 1/4...
# 20   알배추 300g, 대파 흰부분 1토막, 된장 1큰술, 국간장 1/2큰술, 참기름 1...
# 21   감자 3개, 돼지고기 앞다리살 250g, 양파 1/2개, 청양고추 3개, 대파 1/...
# 24   우동면 1인분, 명란젓 1개, 쪽파 1줄, 버터 1조각, 달걀 1개, 김가루 약간,...
# 27   애호박 2개, 계란 3개, 홍고추 1개, 소금 1/2작은술, 참치액젓 1/2큰술, ...
# 29   얼갈이손질전 무게 1kg, 다진마늘 2/3T, 국간장 1T, 갈은깨 1.5T, 들기...
# 31   소고기다짐육 300g, 밥 2공기, 유부 1팩, 쪽파 1줄, 통깨 약간, 진간장 3...
# 34   새송이버섯 3송이, 청양고추 1개, 대파 1/2대, 버터 1T, 간장 5T, 올리고...
# 52   부추 50g, 참치85g 1캔, 달걀 1개, 밥 1공기, 된장15g 1숟가락, 식초...
# 58        참치캔 1개, 양파 1개, 후추 약간, 통깨 약간, 설탕 1꼬집, 소금 1/2t
# 62   소면2인분 200g, 애호박 1개, 소금 2꼬집, 대파 1/2대, 청양고추 1/2개...
# 67   떡국떡 300g, 차돌박이 200g, 새송이버섯 2개, 대파 1대, 청양고추 1개,...
# 72   표고버섯 200g, 꽈리고추 90g, 홍고추 1개, 양파 1/4개, 진간장 2큰술,...
# 82   차돌박이 200g, 부추 100g, 양파 1/2개, 홍고추 1개, 통깨 1숟가락, ...
# 84   새송이버섯 4개, 국거리소고기 150g, 양파 1/2개, 대파 1/2대, 청양고추 ...
# 91   돼지목살 300g, 설탕 1T, 진간장 1-1/4T, 물엿 2T, 간마늘 1/2큰술...
# 101  닭다리살 정육 300g, 소금 약간, 후추 약간, 바질가루 약간, 버터 1숟가락, ...
# 108  양배추 적당히, 두부 1/2모, 참치 180g 1캔, 양파 1/2개, 대파 1/2대...
# 110  돼지목살 300g, 통마늘 1줌 45g, 전분가루1숟가락 20g, 맛술8g 1/2숟...
# 112  바나나 2개, 두부 1/2모, 땅콩버터 60g, 우유 300ml, 소금 약간, 알룰...
# 121  마늘 20개, 표고버섯 8개, 식용유 3T, 고추장 2T, 고춧가루 2T, 올리고당...
# 127                   감자 900g, 모짜렐라 치즈 600g, 청양고추 1-2개
# 135  소면120g 1인분, 냉면육수 1개, 대파 1줌, 진간장 2스푼, 설탕 4스푼, 고...
# 145  새우 300g, 애호박 1개, 올리브유 2T, 참기름 2T, 맛술 1T, 간장 1T...
# 155  파스타면 1인분, 훈제오리 130g, 시금치 100g, 페페론치노 1t, 올리브오일...
# 166  두부면 200g, 참치캔 150g, 토마토퓨레 250g, 엔초비선택 2마리, 양파 ...
# 185  소면 1인분, 어묵 3장, 깻잎 3장, 통깨 약간, 고추장 2숟가락, 고춧가루 1/...
# 188  소고기 불고기용 200g, 꽈리고추 10개, 통깨 약간, 간장 3T, 다진마늘 1T...
# 209  달걀 3개, 미림 1T, 표고버섯 2개, 대파 2대, 양파 1개, 당면 한줌 100...
# 211  가지 1~2개, 양파 1/2개, 밥 1~2공기, 버터 1~1.5큰술, 참치액젓 1큰...
# 221  어묵 4장, 양배추 2장, 당근 조금, 대파 1개, 간장 3T, 굴소스 1T, 물엿...
#
#                                                  tools  \
# 0        키친타올, 믹싱볼, 도마, 조리용나이프, 계량스푼, 프라이팬, 요리스푼, 완성그릇
# 1                볼, 냄비, 계량스푼, 조리주걱, 채반, 도마, 조리용나이프, 접시
# 3                                인덱스도마, 믹싱볼, 요리스푼, 볶음팬
# 5                나무도마, 조리용나이프, 찬기, 숟가락, 프라이팬, 조리주걱, 접시
# 6          도마, 조리용나이프, 볼, 채반, 냄비, 프라이팬, 조리주걱, 계량스푼, 접시
# 7                            도마, 조리용나이프, 소스볼, 계량스푼, 접시
# 8      도마, 조리용나이프, 냄비, 조리용집게, 니트릴장갑, 볼, 소스볼, 조리용스푼, 찬기
# 9            도마, 조리용나이프, 믹싱볼, 채반, 소스볼, 프라이팬, 조리용스푼, 접시
# 10          도마, 조리용나이프, 위생장갑, 유리볼, 요리젓가락, 프라이팬, 플레이팅접시
# 13                                       도마, 프라이팬, 뒤집개
# 20                  도마, 조리용나이프, 내열용기, 전자레인지, 유리볼, 위생장갑
# 21                                      도마, 프라이팬, 요리주걱
# 24                 도마, 유리볼, 휴대용가스버너, 면기, 요리젓가락, 냄비, 채반
# 27     도마, 조리용나이프, 비닐봉지, 볼, 숟가락, 니트릴장갑, 프라이팬, 키친타올, 접시
# 29            니트릴장갑, 믹싱볼, 조리용나이프, 냄비, 조리주걱, 채반, 도마, 접시
# 31     니트릴장갑, 볼, 키친타올, 도마, 조리용나이프, 조리주걱, 프라이팬, 숟가락, 접시
# 34                         나무도마, 믹싱볼, 요리스푼, 프라이팬, 사각접시
# 52     도마, 조리용나이프, 볼, 건지기채망, 조리용스푼, 소스볼, 프라이팬, 뒤집개, 면기
# 58                     도마, 조리용나이프, 프라이팬, 숟가락, 요리스푼, 접시
# 62   니트릴장갑, 도마, 조리용나이프, 믹싱볼, 궁중팬, 요리스푼, 숟가락, 볼, 냄비,...
# 67             볼, 도마, 조리용나이프, 채반, 볶음팬, 요리집게, 조리용스푼, 접시
# 72            도마, 조리용나이프, 계량스푼, 유리계량컵, 프라이팬, 조리용스푼, 접시
# 82            믹싱볼, 도마, 프라이팬, 요리집게, 키친타올, 유리볼, 위생장갑, 가위
# 84              요리용스푼, 볼, 도마, 요리용나이프, 냄비, 프라이팬, 플레이팅접시
# 91          믹싱볼, 요리스푼, 프라이팬, 휴대용가스렌지, 요리용집게, 주방가위, 계량컵
# 101                  밧드트레이, 도마, 프라이팬, 주방집게, 요리스푼, 원형접시
# 108           접시, 도마, 믹싱볼, 프라이팬, 조리용스푼, 전자레인지, 전자레인지용기
# 110      도마, 조리용나이프, 볼, 요리젓가락, 소스볼, 요리스푼, 프라이팬, 플레이팅접시
# 112                           키친타올, 도마, 조리용나이프, 믹서기, 컵
# 121                    도마, 조리용나이프, 소스볼, 프라이팬, 요리스푼, 접시
# 127      감자칼, 믹싱볼, 도마, 조리용나이프, 채반, 요리스푼, 프라이팬, 뒤집개, 접시
# 135                              냄비, 요리젓가락, 채반, 플레이팅접시
# 145              볼, 니트릴장갑, 도마, 조리용나이프, 프라이팬, 조리용스푼, 접시
# 155                 도마, 조리용나이프, 냄비, 요리집게, 프라이팬, 플레이팅접시
# 166          도마, 조리용나이프, 볼, 프라이팬, 조리용스푼, 플레이팅접시, 요리젓가락
# 185   유리볼, 조리용스푼, 도마, 조리용나이프, 냄비, 채망, 조리용젓가락, 위생장갑, 면기
# 188                도마, 키친타올, 프라이팬, 조리주걱, 접시, 소스볼, 계량스푼
# 209                 나무도마, 조리용나이프, 볼, 컵, 프라이팬, 조리주걱, 그릇
# 211                      계량컵, 요리스푼, 도마, 프라이팬, 계량스푼, 면기
# 221                                채칼, 프라이팬, 뒤집기, 원형접시
#
#                                              video_url  \
# 0    https://tv.naver.com/embed/21142287?autoPlay=true
# 1            https://www.youtube.com/embed/hcgBbhPK_4c
# 3            https://www.youtube.com/embed/_pF_uCKx9XU
# 5            https://www.youtube.com/embed/EGWcn41U0zs
# 6    https://tv.naver.com/embed/23435309?autoPlay=true
# 7            https://www.youtube.com/embed/10XCyS-Yn8U
# 8            https://www.youtube.com/embed/H4TL-Ql3NZc
# 9            https://www.youtube.com/embed/yBCk2otlE5s
# 10           https://www.youtube.com/embed/soYa5k2K9os
# 13           https://www.youtube.com/embed/Q6dqEeKbrOY
# 20           https://www.youtube.com/embed/vAq_JQg-8sA
# 21           https://www.youtube.com/embed/A8VTUfcHuRQ
# 24           https://www.youtube.com/embed/UeZ1KV-97kA
# 27           https://www.youtube.com/embed/VUsXWQdnXzk
# 29           https://www.youtube.com/embed/5w7JPVSk8UE
# 31           https://www.youtube.com/embed/k8_iuVqyNNM
# 34           https://www.youtube.com/embed/qkgpxo2-DaQ
# 52           https://www.youtube.com/embed/u5f0dndiSP8
# 58   https://tv.naver.com/embed/68654645?autoPlay=true
# 62           https://www.youtube.com/embed/NzpIT-4s5fo
# 67           https://www.youtube.com/embed/xLkkawphdE0
# 72           https://www.youtube.com/embed/gXdkB28pkwo
# 82           https://www.youtube.com/embed/QRfiJWQC3kM
# 84           https://www.youtube.com/embed/XDnnMi4R_xk
# 91           https://www.youtube.com/embed/OLB8shnr3Nc
# 101          https://www.youtube.com/embed/Uhz_YZzY88s
# 108          https://www.youtube.com/embed/u5Q4aBWqPDA
# 110          https://www.youtube.com/embed/p3XwzBIHqZY
# 112          https://www.youtube.com/embed/TNR_fOHVBSo
# 121          https://www.youtube.com/embed/4OorT8GVXx4
# 127  https://tv.naver.com/embed/26304231?autoPlay=true
# 135          https://www.youtube.com/embed/8lWCQpMkjMc
# 145          https://www.youtube.com/embed/nWQO8s-rTBE
# 155          https://www.youtube.com/embed/h8SdqVYYHbI
# 166          https://www.youtube.com/embed/Fx1I1nTSbgI
# 185          https://www.youtube.com/embed/S86xXH74dMg
# 188          https://www.youtube.com/embed/Oun20Noj6Qw
# 209          https://www.youtube.com/embed/ywtrH2KQwVk
# 211          https://www.youtube.com/embed/e9GMAH6WQU0
# 221          https://www.youtube.com/embed/ToHeC_WVnuo
#
#                                                  steps  \
# 0    [{'text': '다짐육 200g 정도를 준비한 다음 먼저 키친타월로 핏물을 제거...
# 1    [{'text': '비름나물 한 봉지의 무게를 달아보았더니 대략 400g이 나왔어요...
# 3    [{'text': '양파,고추 잘게썰기', 'images': ['https://re...
# 5    [{'text': '양배추는 잘게 채 썰어요.\n나무도마 , 조리용나이프', 'im...
# 6    [{'text': '감자는 5~6mm 정도 두께로 일정하게 썰어준 뒤 먹기 좋게 채...
# 7    [{'text': '토마토는 깨끗이 씻어 반으로 잘라 먹기 좋게 일정한 크기로 썰어...
# 8    [{'text': '취나물은 억센 줄기는 제거하고 연한 줄기와 잎 부분만 남겨 손질...
# 9    [{'text': '껍질벗긴 감자는 일정한 크기로 잘라요 찬물에 헹궈 물기를 탈탈 ...
# 10   [{'text': '깨끗하게 씻은 깻잎은 꼭지와 뾰족한 부분을 자르고 절반으로 잘라...
# 13   [{'text': '두부는(500g) 넓게 잘라 2~3등분 하고 물기를 제거해요.'...
# 20   [{'text': '알배추는 적당한 크기로 썰은 후 깨끗하게 씻어요 씻은 알배추 전...
# 21   [{'text': '양파1/2개 채썰어주고 대파 1/2대, 청양고추 3개 어슷썰기 ...
# 24   [{'text': '명란은 반을 가른 후 칼등으로 밀어 껍질을 제거해요', 'ima...
# 27   [{'text': '세척한 애호박을 1cm 두께로 썰어줍니다. 애호박이 너무 얇으면...
# 29   [{'text': '얼갈이 1키로 준비합니다. 손질전 무게입니다(누런잎 없었습니다)...
# 31   [{'text': '유부는 물기를 꼭 짜요.\n니트릴장갑 , 볼\n유부 손질법', ...
# 34   [{'text': '먼저 새송이 버섯 3동은 밑동을 제거하고 일정한 두께로 잘라 줍...
# 52   [{'text': '부추는 잘게 잘라요.\n도마 , 조리용나이프\n부추 손질법', ...
# 58   [{'text': '양파 넣어서 더욱 맛있는 참치 양파볶음 만들기 해 볼께요.', ...
# 62   [{'text': '애호박 1개 적당한 두께로 채 썬다.\n니트릴장갑 , 도마 , ...
# 67   [{'text': '떡국떡은 물에 10분 정도 불린다.\n볼', 'images': ...
# 72   [{'text': '표고버섯은 밑둥을 제거하고 슬라이스로 썰어주세요 (다른 야채들 ...
# 82   [{'text': '부추는 깨끗하게 세척한 후 3cm 정도로 썰어요', 'image...
# 84   [{'text': '소고기 150g 진간장 1큰술, 참기름 1큰술 넣어 조물조물 밑...
# 91   [{'text': '페이지속 레시피 동영상 시청과!! 유튜브 구독은 레시피 제작에 ...
# 101  [{'text': '닭다리살은 소금, 후추, 바질가루를 뿌려 재료 준비하는 동안 재...
# 108  [{'text': '양파 1/2개, 대파 1/2대, 청양고추 1~2개는 잘게 썰어주...
# 110  [{'text': '목살은 한 입 크기로 잘라요.', 'images': ['http...
# 112  [{'text': '두부는 가볍게 물기를 닦아요.\n키친타올', 'images': ...
# 121  [{'text': '표고버섯은 0.5cm 간격으로 썰어 준비합니다.\n도마 , 조리...
# 127  [{'text': '감자는 깨끗이 씻어 껍질을 벗겨 주세요.\n감자칼 , 믹싱볼',...
# 135  [{'text': '소면을 삶아 찬물에 씻는다.', 'images': []}, {'...
# 145  [{'text': '새우는 꼬리를 제거해 준비해요.\n볼 , 니트릴장갑\n새우 손질...
# 155  [{'text': '시금치는 끝부분을 잘라 손질해요.\n도마 , 조리용나이프\n시금...
# 166  [{'text': '양파는 작은 큐브모양으로 썰어주세요.\n도마 , 조리용나이프',...
# 185  [{'text': '양념 재료를 섞어 양념장을 만들어요\n유리볼 , 조리용스푼\n양...
# 188  [{'text': '꽈리고추는 꼭지를 떼서 손질해요. .\n나무도마', 'image...
# 209  [{'text': '대파는 반으로 갈라 5cm 길이로 넓게 썰어요.\n나무도마 , ...
# 211  [{'text': '분량의 양념을 미리 만들어 주세요. 진간장 2큰술, 설탕 1/2...
# 221  [{'text': '분량의 재료를 채 썰어주세요. 대파는 송송송', 'images'...
#
#                                           final_images  \
# 0    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 1    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 3    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 5    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 6                                                   []
# 7    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 8    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 9    ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 10                                                  []
# 13   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 20   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 21   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 24   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 27   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 29   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 31   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 34   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 52   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 58                                                  []
# 62   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 67                                                  []
# 72   ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 82                                                  []
# 84                                                  []
# 91                                                  []
# 101  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 108  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 110                                                 []
# 112  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 121  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 127                                                 []
# 135                                                 []
# 145  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 155                                                 []
# 166  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 185  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 188                                                 []
# 209                                                 []
# 211  ['https://recipe1.ezmember.co.kr/cache/recipe/...
# 221  ['https://recipe1.ezmember.co.kr/cache/recipe/...
#
#                                                   tips category
# 0    나물 반찬 만들어둔게 있어서 비빔밥 만들어먹을 때 약고추장 넣고 슥슥 비벼서 먹었더...       한식
# 1    비름나물은 데치기전 굵고 억센 줄기는 골라내고 데쳐야 부드러운 나물을 먹을 수 있어...       한식
# 3    취향에 맞게 고추는 더 넣어도 좋아요 싱겁게 드신다면 두부, 감자 ,애호박, 버섯 ...       한식
# 5                                                  NaN       중식
# 6    좋아하는 식감에 따라 데치지 않고 볶아도 되지만 한번 데친 뒤 요리하면 익히기도 쉽...       한식
# 7                      간장소스를 골고루 뿌려 바로 드세요 ^^ 정말 맛있어요~       양식
# 8                                                  NaN       한식
# 9                                                  NaN       한식
# 10                                                 NaN       한식
# 13                                                 NaN       양식
# 20                                                 NaN       한식
# 21                                                 NaN       한식
# 24                                                 NaN       일식
# 27                                                 NaN       한식
# 29   **밥숟가락 계량입니다 **여름철 얼갈이가 억센경우에는 데치는 시간 조금만 늘려주세...       한식
# 31                                                 NaN       일식
# 34                     버섯을 구울때 수분이 빠져나가 쫄깃해질때까지 구워 주세요       양식
# 52                                                 NaN       한식
# 58                                                 NaN       중식
# 62                                                 NaN       일식
# 67                                                 NaN       한식
# 72                                                 NaN       한식
# 82                                                 NaN       한식
# 84                                                 NaN       중식
# 91   생강가루가 없으시면 간생강을 1/10T 정도 아주 소량만 넣어 주시면 됩니다~ 목살...       한식
# 101                                                NaN       양식
# 108                                                NaN       한식
# 110                                                NaN       한식
# 112                                                NaN       간식
# 121                                                NaN       한식
# 127                                                NaN       한식
# 135                                                NaN       한식
# 145                                                NaN       한식
# 155                                                NaN       양식
# 166                                                NaN       양식
# 185                                                NaN       간식
# 188                   간장양념의 경우 양에따라 간보면서 조금씩만 추가해주세요^^       한식
# 209                                                NaN       한식
# 211  ?? 양념 재료 (2인분) : 참치액젓 1.5큰술 진간장 3큰술 설탕 2/3큰술 올...       일식
# 221                          간장을 살짝 눌리면 간장향이 더욱 풍부해져요~       한식

# %%
recipes.shape
# Out:
# (40, 15)

# %%
recipes_tools = (
    recipes.assign(tools=lambda df: df['tools'].str.split(','))
          .explode('tools')
          .assign(tools=lambda df: df['tools'].str.strip())
          .reset_index(drop=True)[['title', 'tools']]
)
recipes_tools[['title', 'tools']]
# Out:
#        title   tools
# 0    소고기 고추장    키친타올
# 1    소고기 고추장     믹싱볼
# 2    소고기 고추장      도마
# 3    소고기 고추장  조리용나이프
# 4    소고기 고추장    계량스푼
# ..       ...     ...
# 272     가지덮밥      면기
# 273  양배추어묵볶음      채칼
# 274  양배추어묵볶음    프라이팬
# 275  양배추어묵볶음     뒤집기
# 276  양배추어묵볶음    원형접시
#
# [277 rows x 2 columns]

# %%
recipes_tools['tools'].unique()
# Out:
# array(['키친타올', '믹싱볼', '도마', '조리용나이프', '계량스푼', '프라이팬', '요리스푼', '완성그릇', '볼',
#        '냄비', '조리주걱', '채반', '접시', '인덱스도마', '볶음팬', '나무도마', '찬기', '숟가락',
#        '소스볼', '조리용집게', '니트릴장갑', '조리용스푼', '위생장갑', '유리볼', '요리젓가락', '플레이팅접시',
#        '뒤집개', '내열용기', '전자레인지', '요리주걱', '휴대용가스버너', '면기', '비닐봉지', '사각접시',
#        '건지기채망', '궁중팬', '요리집게', '유리계량컵', '가위', '요리용스푼', '요리용나이프',
#        '휴대용가스렌지', '요리용집게', '주방가위', '계량컵', '밧드트레이', '주방집게', '원형접시',
#        '전자레인지용기', '믹서기', '컵', '감자칼', '채망', '조리용젓가락', '그릇', '채칼', '뒤집기'],
#       dtype=object)

# %%
recipes_tools.to_csv('recipes_tools.csv', index=False)

# %%
recipes.head(1)
# Out:
#                                           url  \
# 0  https://www.10000recipe.com/recipe/7056958
#
#                                           main_image author    title  \
# 0  https://recipe1.ezmember.co.kr/cache/recipe/20...   반이짝이  소고기 고추장
#
#                                          description  servings  time  \
# 0  더운 여름에 입맛 없을 때 열무김치나 생야채 넣고 비빔밥 만들어먹거나 달걀프라이만 ...         2    20
#
#   difficulty                                          materials  \
# 0         초급  다진소고기 200g, 양파 1/4개, 대파 1/4대, 다진마늘 1큰술, 진간장 1/...
#
#                                            tools  \
# 0  키친타올, 믹싱볼, 도마, 조리용나이프, 계량스푼, 프라이팬, 요리스푼, 완성그릇
#
#                                            video_url  \
# 0  https://tv.naver.com/embed/21142287?autoPlay=true
#
#                                                steps  \
# 0  [{'text': '다짐육 200g 정도를 준비한 다음 먼저 키친타월로 핏물을 제거...
#
#                                         final_images  \
# 0  ['https://recipe1.ezmember.co.kr/cache/recipe/...
#
#                                                 tips category
# 0  나물 반찬 만들어둔게 있어서 비빔밥 만들어먹을 때 약고추장 넣고 슥슥 비벼서 먹었더...       한식

# %%
# 정규표현식 패턴
pattern = r"^(?P<ingredients>[^\d]+?)\s*(?P<quantity>\d+(?:/\d+)?)?\s*(?P<unit>[가-힣a-zA-Z]+)?$"

recipes_ingredients = (
    recipes
    .assign(ingredients=lambda df: df['materials'].str.split(','))  # 재료 리스트 분리
    .explode('ingredients')                                         # 행으로 펼치기
    .assign(ingredients=lambda df: df['ingredients'].str.strip())     # 공백 제거
    .reset_index(drop=True)[['title', 'ingredients']]
)

recipes_ingredients = pd.concat([recipes_ingredients['title'], recipes_ingredients['ingredients'].str.extract(pattern)], axis=1)

recipes_ingredients
# Out:
#        title ingredients quantity unit
# 0    소고기 고추장       다진소고기      200    g
# 1    소고기 고추장          양파      1/4    개
# 2    소고기 고추장          대파      1/4    대
# 3    소고기 고추장        다진마늘        1   큰술
# 4    소고기 고추장         진간장      1/2   큰술
# ..       ...         ...      ...  ...
# 382  양배추어묵볶음          대파        1    개
# 383  양배추어묵볶음          간장        3    T
# 384  양배추어묵볶음         굴소스        1    T
# 385  양배추어묵볶음          물엿        3    T
# 386  양배추어묵볶음         참기름        1    T
#
# [387 rows x 4 columns]

# %%
recipes_ingredients.to_csv('recipes_ingredients.csv', index=False)
